# %% [markdown]
# 1st Step : RAW CSVs and Storage

# %%
import pandas as pd
from pathlib import Path
import os
from google.cloud import storage

# %%
def explore_dataset(path):
    print(f"\n📄 Dataset : {path.name}")
    print("-" * 50)
    
    df = pd.read_csv(path)
    
    print("🔢 Shape:", df.shape)
    display(df.head())
    
    print("\nℹ️ Info:")
    df.info()
    
    print("\n📊 Stats descriptives:")
    display(df.describe(include='all'))
    
    print("\n❓ Valeurs manquantes:")
    display(df.isnull().sum())

# %%
bronze_path = Path("data/bronze")

csv_files = [
    "customers_dataset.csv",
    "sellers_dataset.csv",
    "products_dataset.csv",
    "orders_dataset.csv",
    "order_items_dataset.csv",
    "order_payments_dataset.csv",
    "order_reviews_dataset.csv",
    "geolocation_dataset.csv",
    "product_category_name_translation.csv"
]

# %%
for file in csv_files:
    explore_dataset(bronze_path / file)
# Out:
# 📄 Dataset : customers_dataset.csv
# --------------------------------------------------
# 🔢 Shape: (99441, 5)
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
# ℹ️ Info:
# ...

# %%
# Authentification
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = r"C:\Users\USER\Downloads\ecommerce-analytics-488100-540b9e9c99e9.json"

# Test de connexion
client = storage.Client()
print(client.list_buckets())  # devrait afficher la liste de tes buckets

# %%
#Verification du bucket
[bucket.name for bucket in client.list_buckets()]
# Out:
# ['ecommerce-analytics-bronze-akabi']

# %%
bucket_name = "ecommerce-analytics-bronze-akabi" 

# Chemin vers le dossier bronze local
local_folder = r"C:\Users\USER\Ecommerce-Analytics-Platform\data\bronze"

# Connexion au bucket
bucket = client.bucket(bucket_name)

# Upload automatique de tous les fichiers CSV
for filename in os.listdir(local_folder):
    
    if filename.endswith(".csv"):
        
        local_file_path = os.path.join(local_folder, filename)
        
        # chemin dans le bucket (structure bronze/)
        blob_path = f"bronze/{filename}"
        
        blob = bucket.blob(blob_path)
        
        blob.upload_from_filename(local_file_path)
        
        print(f"✅ Upload réussi : {filename}")

print("\n Tous les fichiers Bronze ont été upload vers GCS")
# Out:
# ✅ Upload réussi : customers_dataset.csv
# ✅ Upload réussi : geolocation_dataset.csv
# ✅ Upload réussi : orders_dataset.csv
# ✅ Upload réussi : order_items_dataset.csv
# ✅ Upload réussi : order_payments_dataset.csv
# ✅ Upload réussi : order_reviews_dataset.csv
# ✅ Upload réussi : products_dataset.csv
# ✅ Upload réussi : product_category_name_translation.csv
# ✅ Upload réussi : sellers_dataset.csv
#
#  Tous les fichiers Bronze ont été upload vers GCS
